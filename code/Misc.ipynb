# %% [markdown]
# # Setup

# %%
# !pwd
# Out:
# /home/umni2/a/umnilab/users/verma99/mk/spr_4711/code

# %%
from mobilkit.umni import *

# %%
import urllib.request

# %% [markdown]
# ## Economic Tracker
# GitHub: https://github.com/OpportunityInsights/EconomicTracker

# %%
def download_oi_ecotracker_data(overwrite=False):
    outfile = Path('../data/_etc/economic_tracker/raw_data.zip')
    url = 'https://github.com/OpportunityInsights/EconomicTracker/archive/main.zip'
    if outfile.exists() and not overwrite:
        return
    urllib.request.urlretrieve(url, U.mkfile(outfile))

# x = download_oi_ecotracker_data(); x # t=0:22

# %% [markdown]
# ## Social Vulnerability Index

# %%
svi = gpd.read_file('../data/_etc/svi/tract/SVI2020_INDIANA_tract.shp').disp()
# Out:
# 1,693 rows x 161 cols; Memory: 2.8 MiB; CRS: EPSG:4269
#          ST     STATE   ST_ABBR    STCNTY    COUNTY         FIPS  \
#    <object>  <object>  <object>  <object>  <object>     <object>
# 0        18   Indiana        IN     18001     Adams  18001030100
#
#                                   LOCATION  AREA_SQMI E_TOTPOP M_TOTPOP  \
#                                   <object>  <float64>  <int64>  <int64>
# 0  Census Tract 301, Adams County, Indiana   77.63825     4975      403
#
#       E_HU     M_HU     E_HH     M_HH E_POV150 M_POV150  E_UNEMP  M_UNEMP  \
#    <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0     1977      189     1882      174      489      172       76       58
#
#    E_HBURD  M_HBURD E_NOHSDP M_NOHSDP E_UNINSUR M_UNINSUR  E_AGE65  M_AGE65  \
#    <int64>  <int64>  <int64>  <int64>   <int64>   <int64>  <int64>  <int64>
# 0      185       67      206      103       224       112     1040      238
#
#    E_AGE17  M_AGE17 E_DISABL M_DISABL E_SNGPNT M_SNGPNT E_LIMENG M_LIMENG  \
#    <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0     1180      171      583      204       32       35        0       48
#
#   E_MINRTY M_MINRTY  E_MUNIT  M_MUNIT E_MOBILE M_MOBILE  E_CROWD  M_CROWD  \
#    <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0      322      166       21       27       66       47        5       14
#
#    E_NOVEH  M_NOVEH E_GROUPQ M_GROUPQ  EP_POV150  MP_POV150   EP_UNEMP  \
#    <int64>  <int64>  <int64>  <int64>  <float64>  <float64>  <float64>
# 0       20       19        0       12        9.8        3.4        3.1
#
#     MP_UNEMP  ...  F_AGE17 F_DISABL F_SNGPNT F_LIMENG F_THEME2 F_MINRTY  \
#    <float64>  ...  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0        2.3  ...        0        0        0        0        0        0
#
#   F_THEME3  F_MUNIT F_MOBILE  F_CROWD  F_NOVEH F_GROUPQ F_THEME4  F_TOTAL  \
#    <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0        0        0        0        0        0        0        0        0
#
#   E_DAYPOP  E_NOINT  M_NOINT   E_AFAM   M_AFAM   E_HISP   M_HISP  E_ASIAN  \
#    <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>  <int64>
# 0     3680      589      599        0       12      300      161        0
#
#    M_ASIAN   E_AIAN   M_AIAN   E_NHPI   M_NHPI E_TWOMORE M_TWOMORE E_OTHERRAC  \
#    <int64>  <int64>  <int64>  <int64>  <int64>   <int64>   <int64>    <int64>
# 0       12        5       12        0       12        17        36          0
#
#   M_OTHERRAC   EP_NOINT   MP_NOINT    EP_AFAM    MP_AFAM    EP_HISP  \
#      <int64>  <float64>  <float64>  <float64>  <float64>  <float64>
# 0         12       11.8        1.0        0.0        0.7        6.0
#
#      MP_HISP   EP_ASIAN   MP_ASIAN    EP_AIAN    MP_AIAN    EP_NHPI  \
#    <float64>  <float64>  <float64>  <float64>  <float64>  <float64>
# 0        3.3        0.0        0.7        0.1        0.2        0.0
#
#      MP_NHPI EP_TWOMORE MP_TWOMORE EP_OTHERRA MP_OTHERRA SHAPE_STAr  \
#    <float64>  <float64>  <float64>  <float64>  <float64>  <float64>
# 0        0.7        0.3        0.7        0.0        0.7   0.021526
#
#   SHAPE_STLe                                           geometry
#    <float64>                                         <geometry>
# 0    0.77535  POLYGON ((-85.073861 40.917823, -85.053433 40....
#
# [2 rows x 161 columns]
